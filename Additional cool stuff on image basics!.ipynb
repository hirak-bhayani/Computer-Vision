# %%
pip install --upgrade pip
# Out:
# Python interpreter will be restarted.
# Looking in indexes: https://pypi.org/simple, https://aws:****@uplift-prod-410757048423.d.codeartifact.us-east-1.amazonaws.com/pypi/uplift-prod/simple/
# ...
#   Using cached https://uplift-prod-410757048423.d.codeartifact.us-east-1.amazonaws.com/pypi/uplift-prod/simple/pip/23.1.2/pip-23.1.2-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ...
# Python interpreter will be restarted.

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://aws:****@uplift-prod-410757048423.d.codeartifact.us-east-1.amazonaws.com/pypi/uplift-prod/simple/
# ...
#   Using cached https://uplift-prod-410757048423.d.codeartifact.us-east-1.amazonaws.com/pypi/uplift-prod/simple/opencv-python/4.7.0.72/opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("/dbfs/FileStore/tables/hirak/R&R/CV/DATA/dog_backpack.png")

# %%
# Wrong RGB Order!
plt.imshow(img)
# Out:
# Out[4]: <matplotlib.image.AxesImage at 0x7fdf7f725dc0>

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
# Out:
# Out[5]: <matplotlib.image.AxesImage at 0x7fdfc58f47c0>

# %% [markdown]
# #### Flipping the image upside down and displaying it in the notebook.

# %%
new_img = img_rgb
new_img = cv2.flip(new_img,0)
plt.imshow(new_img)
# Out:
# Out[6]: <matplotlib.image.AxesImage at 0x7fdfc586d970>

# %% [markdown]
# #### Drawing an empty RED rectangle around the dogs face and displaying the image in the notebook.

# %%
plt.imshow(img_rgb)
# Out:
# Out[7]: <matplotlib.image.AxesImage at 0x7fdfc58517f0>

# %%
cv2.rectangle(img_rgb,pt1=(200,380),pt2=(600,700),color=(255,0,0),thickness=10)
plt.imshow(img_rgb)
# Out:
# Out[8]: <matplotlib.image.AxesImage at 0x7fdfc57b4be0>

# %% [markdown]
# #### Drawing a BLUE TRIANGLE in the middle of the image.

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
vertices = np.array([[250,800],[425,300],[600,700]],np.int32)
pts = vertices.reshape((-1,1,2))

cv2.polylines(img_rgb,[pts],isClosed=True,color=(0,0,255),thickness=20)
plt.imshow(img_rgb)
# Out:
# Out[9]: <matplotlib.image.AxesImage at 0x7fdfc5725340>

# %%
#Filling in the triangle
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
vertices = np.array([[250,700],[425,400],[600,700]],np.int32)
pts = vertices.reshape((-1,1,2))

cv2.fillPoly(img_rgb,[pts],color=(0,0,255))
plt.imshow(img_rgb)
# Out:
# Out[10]: <matplotlib.image.AxesImage at 0x7fdfc5709370>

# %% [markdown]
# #### Script that opens the picture and allows me to draw empty red circles whenver I right click my mouse down

# %%
import cv2
import numpy as np
# Create a function based on a CV2 Event (Left button click)
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),100,(0,0,255),10)

# Open Image
img = cv2.imread("../DATA/dog_backpack.png")
# This names the window so we can reference it 
cv2.namedWindow(winname='dog')
# Connects the mouse button to our callback function
cv2.setMouseCallback('dog',draw_circle)

while True: #Runs forever until we break with Esc key on keyboard
    # Shows the image window
    cv2.imshow('dog',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break
# Once script is done, its usually good practice to call this line
# It closes all windows (just in case you have multiple windows called)
cv2.destroyAllWindows()
